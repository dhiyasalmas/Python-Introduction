# %% [markdown]
# <a href="https://colab.research.google.com/github/dhiyasalmas/Python-Introduction/blob/main/Quiz_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Quiz 1 (2 Jam)**
#
# Mari berdoa terlebih dahulu sebelum memulai quiz hari ini.
#
# Semangat Adiiii!

# %% [markdown]
# # **Soal 1 (20 poin)**
#
# Buatlah program untuk menghapus angka yang sama pada list berikut
#
# a = [0, 1, 1, 2, 3, 4, 4, 5, 5, 6, 7, 8, 9]

# %% [markdown]
# # **Soal 2 (20 poin)**
#
# Buatlah program untuk menghitung invers matriks berikut
#
# a = [[1,2],[3,4]]

# %% [markdown]
# # **Soal 3 (60 poin)**
#
# Buatlah program kasir sederhana dimana terdapat 15 menu (8 makanan dan 7 minuman), dimana user dapat memilih beberapa menu. Output program harus menjumlahkan total pembelian user dan uang kembaliannya.
