# %% [markdown]
# <a href="https://colab.research.google.com/github/dhiyasalmas/Python-Introduction/blob/main/Quiz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quiz 2 (2 jam)
#
# Mari berdoa terlebih dahulu sebelum memulai quiz hari ini.
#
# Semangat Adiiii!

# %% [markdown]
# # **Perhatikan Algoritma Berikut**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Soal 1
# Buatlah program untuk menyelesaikan persamaan
#
# $$ \int^{3}_{1} x^{2} + 2x +5 $$

# %% [markdown]
# # Soal 2
#
# Buatlah program untuk menyelesaikan persamaan
#
# $$ \int^{1}_{3} \int^{2}_{0} xy^{2}+2x^{2}y+2x+3y=5 $$
